# %% [markdown]
# # Week 2 proof of life
# CML3112. Set STUDENT_ID to your Student Registration Number, including slashes (fictional example only: 99/TEST/000/DEMO-X). Run cells in order.

# %%
STUDENT_ID = "24/1755/BSCE-S"
COHORT = "CML3112"

# %%
print("Hello from CML3112")
proof_sum = 2 + 2
print(proof_sum)
# Out:
# Hello from CML3112
# 4

# %%
readings = 12

# %%
readings = readings + 5
print(readings)
# Out:
# 17

# %% [markdown]
# Run the previous cell three times. Explain the changing result below, then restart and run all.

# %% [markdown]
# My explanation:
# Because a Jupyter notebook maintains a persistent kernel state, variables retain their modified values across cell runs. Executing Cell 4 assigns readings a value of 12. Re-running Cell 5 (readings = readings + 5) consecutively causes cumulative mutation—stepping the value from 17 to 22 to 27—because each run operates on the previous run's output. To eliminate this side effect and ensure reproducible results, the kernel must be restarted and the cells executed in linear order.

# %%
import csv
with open("site_inspection_log.csv", newline="") as f:
    rows = list(csv.DictReader(f))
print(len(rows))
# Out:
# 4

# %% [markdown]
# After Restart and Run All, expected outputs include 4, 17 and 4 rows. Save with slashes replaced by underscores in the filename only, for example 99_TEST_000_DEMO-X_W02.ipynb.
